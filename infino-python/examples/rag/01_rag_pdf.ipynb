# %% [markdown]
# # Build a RAG pipeline in Python over arXiv papers with Infino
#
# This notebook builds a complete **Retrieval-Augmented Generation (RAG)** pipeline over real arXiv research papers using [Infino](https://pypi.org/project/infino/) — a single engine that stores your data as Apache Parquet on local disk or object storage and runs **SQL, full-text (BM25), and vector search** over it. No separate vector database to run or keep in sync.
#
# **What you'll do:**
# 1. Pull a sample of arXiv ML papers from the HuggingFace Hub.
# 2. Chunk and embed them locally (no API key).
# 3. Index them in an Infino table on local disk.
# 4. Retrieve the most relevant chunks for a question with vector search.
# 5. Assemble a grounded prompt and (optionally) generate an answer.
#
# Everything except the optional final answer runs locally and key-free — copy, paste, run.

# %% [markdown]
# ## Setup
#
# Install the dependencies (skip if you already ran `pip install -r requirements.txt`):

# %%
# %pip install infino pyarrow sentence-transformers datasets

# %%
import sys
from pathlib import Path

# Make the repo's shared helpers importable.
sys.path.insert(0, str(Path.cwd().parent))

import shutil

import infino
import pyarrow as pa

from _shared.embedding import DIM, METRIC, embed, embed_query, as_vector_column
from _shared.chunking import chunk_text
from _shared.loaders import load_arxiv

# %% [markdown]
# ## 1. Load arXiv papers
#
# Stream a sample of arXiv ML papers (title + abstract) from the HuggingFace Hub. Raise `n` to index more.

# %%
papers = load_arxiv(n=200)
print(f"loaded {len(papers)} papers")
print(papers[0]["title"])
print(papers[0]["abstract"][:300], "...")
# Out:
# loaded 200 papers
# Learning from compressed observations
# The problem of statistical learning is to construct a predictor of a random
# variable $Y$ as a function of a related random variable $X$ on the basis of an
# i.i.d. training sample from the joint distribution of $(X,Y)$. Allowable
# predictors are drawn from some specified class, and the goal is to appro ...

# %% [markdown]
# ## 2. Chunk and embed
#
# Split each abstract into overlapping word windows and embed every chunk locally with `all-MiniLM-L6-v2` (384-dim, normalized). Keep the paper title alongside each chunk so we can cite the source.

# %%
titles, texts = [], []
for paper in papers:
    for chunk in chunk_text(paper["abstract"]):
        titles.append(paper["title"])
        texts.append(chunk)

print(f"{len(texts)} chunks from {len(papers)} papers")
embeddings = embed(texts)  # first call downloads the small model
# Out:
# 347 chunks from 200 papers

# %% [markdown]
# ## 3. Index in Infino (local disk)
#
# Connect to a **local** catalog (just a directory — no server, no S3 setup), declare a schema, and index two columns: `text` for full-text search and `emb` for vector search. The `_id` column is added automatically. One `append` is one atomic commit.

# %%
DB_DIR = "./arxiv_rag_data"
shutil.rmtree(DB_DIR, ignore_errors=True)  # start fresh each run

db = infino.connect(DB_DIR)
schema = pa.schema([
    pa.field("title", pa.large_utf8(), nullable=False),
    pa.field("text", pa.large_utf8(), nullable=False),
    pa.field("emb", pa.list_(pa.float32(), DIM), nullable=False),
])
spec = infino.IndexSpec().fts("text").vector("emb", DIM, n_cent=256, metric=METRIC)
table = db.create_table("papers", schema, spec)

table.append(pa.record_batch([
    pa.array(titles, type=pa.large_utf8()),
    pa.array(texts, type=pa.large_utf8()),
    as_vector_column(embeddings),
], schema=schema))

n = db.query_sql("SELECT COUNT(*) AS n FROM papers").to_pydict()["n"][0]
print(f"indexed {n} chunks")
# Out:
# indexed 347 chunks

# %% [markdown]
# ## 4. Retrieve
#
# Embed the question and run vector k-NN. `projection` names the columns to return. With a cosine index a **smaller score is nearer**.

# %%
def retrieve(question: str, k: int = 4):
    res = table.vector_search(
        "emb", embed_query(question), k=k,
        projection=["title", "text", "score"],
    ).to_pydict()
    return list(zip(res["title"], res["text"], res["score"]))


question = "How do neural networks learn representations from data?"
hits = retrieve(question)
for title, text, score in hits:
    print(f"[{score:.3f}] {title[:70]}\n  {text[:160]}...\n")
# Out:
# [0.569] Automatic Pattern Classification by Unsupervised Learning Using
#   Dime
#   presented is reproduced at the output by back propagating the error. The mirroring neural network is capable of reducing the input vector to a great degree (app...
#
# [0.595] When is there a representer theorem? Vector versus matrix regularizers
#   We consider a general class of regularization methods which learn a vector of parameters on the basis of linear measurements. It is well known that if the regul...
#
# [0.617] Statistical Mechanics of Nonlinear On-line Learning for Ensemble
#   Tea
#   We analyze the generalization performance of a student in a model composed of nonlinear perceptrons: a true teacher, ensemble teachers, and the student. We calc...
#
# [0.624] Positive factor networks: A graphical framework for modeling
#   non-neg
# ...

# %% [markdown]
# ## 5. Generate a grounded answer
#
# Assemble the retrieved chunks into a prompt and answer it. The `_shared.llm` helper uses Azure AI Foundry or OpenAI if configured (see the README), and returns `None` otherwise — so the notebook always runs, printing the grounded context when there is no LLM.

# %%
from _shared.llm import complete

context = "\n\n".join(f"[{i + 1}] {title}: {text}" for i, (title, text, _) in enumerate(hits))
prompt = (
    "Answer the question using only the context passages. Cite them as [n]. "
    "If the answer isn't in the context, say so.\n\n"
    f"Context:\n{context}\n\nQuestion: {question}\nAnswer:"
)

reply = complete(prompt)
print(reply if reply else f"No LLM configured — grounded context that would be sent:\n\n{prompt}")
# Out:
# Neural networks can learn representations by compressing input data into a reduced internal code and then reconstructing the original input from that code. In the mirroring neural network described in the context, the network “reduce[s] the input vector to a great degree” and reconstructs the input at the output layer; the “feature set” is taken from the central hidden layer, which serves as the learned representation [1].
#
# The context also describes learning in terms of adjusting parameters from data using error backpropagation [1], and more generally as learning a vector or matrix of parameters from linear measurements under regularization, where the learned parameters can be expressed in relation to the input data [2]. In online nonlinear perceptron models, learning rules such as Hebbian learning and perceptron learning shape how the student model generalizes from examples [3].

# %% [markdown]
# ## What just happened
#
# One Infino table on local disk held the paper text **and** its vector index — no separate vector database. The same table is also full-text searchable (`table.bm25_search(...)`) and SQL-queryable (`db.query_sql(...)`) over the exact same rows.
#
# **Next:** [`02_hybrid_rag.ipynb`](02_hybrid_rag.ipynb) combines keyword and vector search in a single query for higher recall.
